# %%
import pandas as pd

# %%
URL = "https://docs.google.com/spreadsheets/d/1PU5rWDZYtIdxdoXRh1EmhFtmNOazvWkt3iV30FJLgdA/edit?usp=sharing"

# %%
path = 'https://drive.google.com/uc?export=download&id=1PU5rWDZYtIdxdoXRh1EmhFtmNOazvWkt3iV30FJLgdA'

# %%
SHEET_ID = "1PU5rWDZYtIdxdoXRh1EmhFtmNOazvWkt3iV30FJLgdA"

# %%
df = pd.read_csv(
    'https://docs.google.com/spreadsheets/d/' + SHEET_ID + '/export?gid=0&format=csv'
)

# %%
from utils_local import read_spreadsheet

# %%
df = read_spreadsheet(gid_key="granularity")

# %%
df
# Out:
#           Unnamed: 0  Gym99 Unnamed: 2 Gym288 Unnamed: 4 Vault (6) Unnamed: 6  \
# 0                NaN  Video      Class  Video      Class     Video      Class
# 1               None  89.41       84.4  84.71      50.01     41.26      24.67
# 2             SeLaVi  88.93      84.75  83.68      52.82     43.72      25.44
# 3             RSPNet  91.28      87.59  86.11       55.2     43.72      33.35
# 4          VideoMoCo  90.54      86.36  85.31      54.07     45.74      27.78
# 5   Pretext-contrast  90.31       85.7  85.42      52.66     46.19      28.48
# 6                CTP  92.17      88.33  87.33      56.51     44.17      26.83
# 7               TCLR  91.49      87.97  86.93      55.37     46.19      29.84
# 8                GDT  90.36      86.46  85.74      55.36     44.62      33.11
# 9           AVID-CMA  90.56      85.83  85.96      52.46     45.52      30.35
# 10        Supervised  91.77         88  87.63       58.4     49.33      37.65
# ...
